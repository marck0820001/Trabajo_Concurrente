# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
df = pd.read_csv('../data/raw/Plantaciones_TOTAL.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4484178 entries, 0 to 4484177
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID PLANTACION          int64
#  1   PERIODO                float64
#  2   DEPARTAMENTO           object
#  3   PROVINCIA              object
#  4   DISTRITO               object
#  5   ARFFS                  object
#  6   SEDE                   object
#  7   UBIGEO                 int64
#  8   FINALIDAD              object
#  9   NUMERO CERTIFICADO     object
#  10  TITULAR                object
#  11  TIPO PERSONA           object
#  12  TIPO DOCUMENTO         object
#  13  NUMERO DOCUMENTO       object
#  14  REGIMEN TENENCIA       object
#  15  TIPO PLANTACION        object
#  16  ESPECIE                object
#  17  SUPERFICIE PLANTACION  float64
#  18  FECHA CORTE            int64
# dtypes: float64(2), int64(3), object(14)
# memory usage: 650.0+ MB

# %%
df.drop(columns='ID PLANTACION', inplace=True)

# %%
df["PERIODO"] = df["PERIODO"].fillna(0).astype(int)

# %%
df["FECHA CORTE"] = pd.to_datetime(df["FECHA CORTE"].astype(str), format="%Y%m%d", errors='coerce')
df["FECHA CORTE"] = df["FECHA CORTE"].map(lambda x: x.toordinal() if pd.notnull(x) else 0)

# %%
df["NUMERO DOCUMENTO"] = df["NUMERO DOCUMENTO"].astype(str)

# %%
df.head()
# Out:
#    PERIODO DEPARTAMENTO  PROVINCIA DISTRITO          ARFFS        SEDE  \
# 0     2016       ANCASH     YUNGAY   YUNGAY   ATFFS Áncash      HUARAZ
# 1     2018     AMAZONAS  UTCUBAMBA  JAMALCA  GORE Amazonas  POMACOCHAS
# 2     2018     AMAZONAS  UTCUBAMBA  JAMALCA  GORE Amazonas  POMACOCHAS
# 3     2018     AMAZONAS  UTCUBAMBA  JAMALCA  GORE Amazonas  POMACOCHAS
# 4     2018     AMAZONAS  UTCUBAMBA  JAMALCA  GORE Amazonas  POMACOCHAS
#
#    UBIGEO   FINALIDAD           NUMERO CERTIFICADO  \
# 0   22001  PRODUCCIÓN      02-ANC/REG-PLT-2016-064
# 1   10705  PRODUCCIÓN  01-AMA-BON/REG-PLT-2018-127
# 2   10705  PRODUCCIÓN  01-AMA-BON/REG-PLT-2018-129
# 3   10705  PRODUCCIÓN  01-AMA-BON/REG-PLT-2018-135
# 4   10705  PRODUCCIÓN  01-AMA-BON/REG-PLT-2018-139
#
#                               TITULAR     TIPO PERSONA TIPO DOCUMENTO  \
# 0          CHAVEZ BARTOLOME, IGNACIO   PERSONA NATURAL            DNI
# 1               ROJAS TARRILLO, ALEX   PERSONA NATURAL            DNI
# 2          CAMACHO SANCHEZ, SANTIAGO   PERSONA NATURAL            DNI
# 3  REGALADO TERRONES, JOSÉ PRIMITIVO   PERSONA NATURAL            DNI
# 4           OBLITAS TARRILLO, RAMIRO   PERSONA NATURAL            DNI
#
#   NUMERO DOCUMENTO REGIMEN TENENCIA TIPO PLANTACION              ESPECIE  \
# 0         33323776   PREDIO PRIVADO         ARBOLES  Eucalyptus globulus
# 1         33656772   PREDIO PRIVADO         ARBOLES         Pinus patula
# 2         33656754   PREDIO PRIVADO         ARBOLES   Eucalyptus saligna
# 3         45281628   PREDIO PRIVADO         ARBOLES         Pinus patula
# 4         45771363   PREDIO PRIVADO         ARBOLES   Eucalyptus saligna
#
#    SUPERFICIE PLANTACION  FECHA CORTE
# 0                  24.74       738216
# 1                   0.61       738216
# 2                   0.58       738216
# 3                   0.96       738216
# 4                   0.50       738216

# %%
df.drop(columns=[
    "NUMERO CERTIFICADO",  # ID único
    "NUMERO DOCUMENTO",    # Identificador personal
    "TITULAR",             # Nombre no relevante para clustering
    "UBIGEO"               # Redundante si ya usamos DEPARTAMENTO, PROVINCIA, DISTRITO, y SEDE
], inplace=True)

# %%
categorical_cols = [
    "DEPARTAMENTO", "PROVINCIA", "DISTRITO",
    "ARFFS", "SEDE", "FINALIDAD", "TIPO PERSONA",
    "TIPO DOCUMENTO", "REGIMEN TENENCIA",
    "TIPO PLANTACION", "ESPECIE"
]


le = LabelEncoder()
for col in categorical_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df.head()
# Out:
#    PERIODO  DEPARTAMENTO  PROVINCIA  DISTRITO  ARFFS  SEDE  FINALIDAD  \
# 0     2016             1        167       801     13    16          0
# 1     2018             0        160       313     14    26          0
# 2     2018             0        160       313     14    26          0
# 3     2018             0        160       313     14    26          0
# 4     2018             0        160       313     14    26          0
#
#    TIPO PERSONA  TIPO DOCUMENTO  REGIMEN TENENCIA  TIPO PLANTACION  ESPECIE  \
# 0             2               1                 5                0      202
# 1             2               1                 5                0      395
# 2             2               1                 5                0      204
# 3             2               1                 5                0      395
# 4             2               1                 5                0      204
#
#    SUPERFICIE PLANTACION  FECHA CORTE
# 0                  24.74       738216
# 1                   0.61       738216
# 2                   0.58       738216
# 3                   0.96       738216
# 4                   0.50       738216

# %%
df.drop(columns=[
    "ARFFS",
    "TIPO DOCUMENTO",
    "FECHA CORTE"
], inplace=True)

# %%
df.head()
# Out:
#    PERIODO  DEPARTAMENTO  PROVINCIA  DISTRITO  SEDE  FINALIDAD  TIPO PERSONA  \
# 0     2016             1        167       801    16          0             2
# 1     2018             0        160       313    26          0             2
# 2     2018             0        160       313    26          0             2
# 3     2018             0        160       313    26          0             2
# 4     2018             0        160       313    26          0             2
#
#    REGIMEN TENENCIA  TIPO PLANTACION  ESPECIE  SUPERFICIE PLANTACION
# 0                 5                0      202                  24.74
# 1                 5                0      395                   0.61
# 2                 5                0      204                   0.58
# 3                 5                0      395                   0.96
# 4                 5                0      204                   0.50

# %%
selected_features = [
    "PERIODO",
    "DEPARTAMENTO",
    "PROVINCIA",
    "DISTRITO",
    "SEDE",
    "FINALIDAD",
    "TIPO PERSONA",
    "REGIMEN TENENCIA",
    "TIPO PLANTACION",
    "ESPECIE",
    "SUPERFICIE PLANTACION"
]

df_filtered = df[selected_features]

# %%
df_filtered.head()
# Out:
#    PERIODO  DEPARTAMENTO  PROVINCIA  DISTRITO  SEDE  FINALIDAD  TIPO PERSONA  \
# 0     2016             1        167       801    16          0             2
# 1     2018             0        160       313    26          0             2
# 2     2018             0        160       313    26          0             2
# 3     2018             0        160       313    26          0             2
# 4     2018             0        160       313    26          0             2
#
#    REGIMEN TENENCIA  TIPO PLANTACION  ESPECIE  SUPERFICIE PLANTACION
# 0                 5                0      202                  24.74
# 1                 5                0      395                   0.61
# 2                 5                0      204                   0.58
# 3                 5                0      395                   0.96
# 4                 5                0      204                   0.50

# %%
numeric_cols = ["PERIODO", "SUPERFICIE PLANTACION"]

# --- 2) StandardScaler SOLO a esas columnas --------
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# --- 3) guarda la matriz para Go -------------------
df.to_csv("matrix.csv", index=False)

# --- 4) guarda medias y sigmas en JSON -------------
scaler_json = {
    "cols":  numeric_cols,
    "mean":  scaler.mean_.tolist(),
    "std":   scaler.scale_.tolist()
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 17
#      11 scaler_json = {
#      12     "cols":  numeric_cols,
#      13     "mean":  scaler.mean_.tolist(),
#      14     "std":   scaler.scale_.tolist()
#      15 }
#      16 with open("scaler.json", "w") as f:
# ---> 17     json.dump(scaler_json, f, indent=2)
#      19 print("✅ matrix.csv  +  scaler.json listos")
#
# NameError: name 'json' is not defined

# %%
with open("scaler.json", "w") as f:
    json.dump(scaler_json, f, indent=2)

print("✅ matrix.csv  +  scaler.json listos")
# Out:
# ✅ matrix.csv  +  scaler.json listos
